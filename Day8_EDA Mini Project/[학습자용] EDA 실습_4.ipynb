# %% [markdown]
# # EDA 실습 4

# %% [markdown]
# * 이번 시간은 주어진 데이터를 활용해 자유롭게 EDA 실습을 진행하는 시간입니다.

# %%
# !pip install seaborn
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
dataset = sns.dataset.
