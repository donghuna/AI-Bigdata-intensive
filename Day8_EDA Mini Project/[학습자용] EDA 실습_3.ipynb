# %% [markdown]
# # EDA 실습 3

# %% [markdown]
# * 이번 시간은 주어진 NBA 데이터를 활용해 자유롭게 EDA 실습을 진행하는 시간입니다.

# %% [markdown]
# | Column ID |  Column Name   | Data type | Values type |         Description          |
# | :-------: | :------------: | :-------: | :---------: | :--------------------------: |
# |     0     |      Player       |   object   |  Discrete  |        선수 이름         |
# |     1     |   POS    |  object   |  Discrete   |     선수의 포지션      |
# |     2     |     Age     |   int64   |  Continous  |        선수의 나이          |
# |     3     |   Tm    |  object   |  Discrete   |  선수의 소속팀  |
# |     4     | G  |   int64   |  Continous  | 경기 수 |
# |     5     | 3P% |   int64   |  Continous  |   3점슛 성공률   |
# |     6     |   2P&   |   int64   |  Continous  |     2점슛 성공률     |
# |     7     |  eFG%  |  int64   |  Continous   |    야투율    |
# |     8     |      FT%      |  int64   |  Continous   |        자유투 성공률        |
# |     9     |      TRB       |  int64   |  Continous   |        리바운드 점유율         |
# |    10     |  AST  |   int64   |  Continous  |    경기당 어시스트 개수    |
# |    11     |  STL  |   int64   |  Continous  |    경기당 스틸 개수    |
# |    12     | BLK |   int64   |  Continous  |   경기당 블락 개수   |
# |    13     | TOV |  int64   |  Continous   |   경기당 턴오버 개수   |
# |    14     |     PS/G     |  int64   |  Continous   |  경기당 패스  |
# |    15     |     Season     |  object   |  Discrete   |  해당 시즌  |
#
# * NBA 데이터로 하는 것이 어려우신 분들은 seaborn에 있는 titanic 데이터셋을 load 해서 실습해보시기 바랍니다.

# %%
# !pip install seaborn
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
